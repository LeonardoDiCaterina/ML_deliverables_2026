# %% [markdown]
# # Python Refresher for Data Science
#
# This notebook provides a practical refresher of Python fundamentals essential for data science, using real data from the Exercise1.xlsx file.

# %% [markdown]
# # 1. Data Types and Variables
#
# Python has several basic data types that are fundamental to working with data:
# - **int**: Integers (whole numbers)
# - **float**: Floating-point numbers (decimals)
# - **str**: Strings (text)
# - **bool**: Boolean (True/False)
# - **list**: Ordered collection of items
# - **dict**: Unordered collection of key-value pairs

# %% [markdown]
# __`Step 1`__ Create variables of different types and check their data type using the `type()` function.

# %%
# Integer
int_value = 42
print(type(int_value))  # Output: <class 'int'>
# Float
float_value = 3.14
print(type(float_value))  # Output: <class 'float'>
# String
string_value = "Hello, World!"
print(type(string_value))  # Output: <class 'str'>
# Boolean
boolean_value = True
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# # 2. Lists and Basic Operations
#
# Lists are ordered collections that can hold multiple items. They are mutable (can be changed) and are indexed starting from 0.

# %% [markdown]
# __`Step 2`__ Create a list and access elements using indexing.

# %%
# Create a list of features
my_list= [1, 2, 3, 4, 5, 5]
# Access elements by index
print(my_list[0])  # Output: 1
# Get length of list
print(len(my_list))  # Output: 5
# Out:
# 1
# 6

# %% [markdown]
# __`Step 3`__ Modify lists using append, insert, and remove operations.

# %%
# Start with a list

# Append (add to end)
my_list.append(6)
# Insert at specific position
my_list.insert(0, 0)  # Insert 0 at index 0
# Remove specific item
my_list.remove(3)  # Remove the first occurrence of 3

# %% [markdown]
# # 3. Dictionaries
#
# Dictionaries store data as key-value pairs. They are very useful for organizing related data.

# %% [markdown]
# __`Step 4`__ Create and manipulate dictionaries.

# %%
# Create a dictionary
my_dictioniary = {
    "name": "Alice",
    "age": 30,
    "city": "New York"
}

# Access values using keys
my_dictioniary["name"]  # Output: 'Alice'
my_dictioniary.get("age")  # Output: 30

# Add new key-value pair
my_dictioniary["email"] = "alice@example.com"

# Get all keys and values
keys = my_dictioniary.keys()  # Output: dict_keys(['name', 'age', 'city', 'email'])
values = my_dictioniary.values()  # Output: dict_values(['Alice', 30, 'New York', 'alice@example.com'])
items = my_dictioniary.items()  # Output: dict_items([('name', 'Alice'), ('age', 30), ('city', 'New York'), ('email', '
print(items)  # Output: dict_items([('name', 'Alice'), ('age', 30), ('city', 'New York'), ('email', '
# Out:
# dict_items([('name', 'Alice'), ('age', 30), ('city', 'New York'), ('email', 'alice@example.com')])

# %% [markdown]
# # 4. Control Flow: Conditionals (if/else)
#
# Conditionals allow us to execute different code based on conditions.

# %% [markdown]
# __`Step 5`__ Use if/else statements to make decisions.

# %%
age = 30
if age < 18:
    print("no beer for you")
elif age < 21:
    print("have a beer, but only light beer")
else:
    print("have a beer")
# Out:
# have a beer

# %% [markdown]
# # 5. Loops: for and while
#
# Loops allow us to repeat code multiple times.

# %% [markdown]
# __`Step 6`__ Use for loops to iterate over lists.

# %%
# For loop over a list

for item in my_list:
    print(item)

# For loop with index
for i in range(len(my_list)):
    print(f"Index: {i}, Value: {my_list[i]}")
# Out:
# 0
# 1
# 2
# 4
# 5
# 5
# 6
# Index: 0, Value: 0
# Index: 1, Value: 1
# Index: 2, Value: 2
# Index: 3, Value: 4
# Index: 4, Value: 5
# Index: 5, Value: 5
# Index: 6, Value: 6

# %% [markdown]
# __`Step 7`__ Use while loops for conditional repetition.

# %%
# While loop
import random
random_number = 0
security_counter = 10000
while random_number != 5:
    print(f"Random Number: {random_number}")
    random_number = random.randint(6, 10)
    security_counter -= 1
    if security_counter <= 0:
        print("Security counter reached zero, breaking loop to prevent infinite execution.")
        break
# Out:
# Random Number: 0
# Random Number: 9
# Random Number: 6
# Random Number: 10
# Random Number: 6
# Random Number: 9
# Random Number: 7
# Random Number: 10
# Random Number: 9
# Random Number: 8
# Random Number: 10
# Random Number: 8
# Random Number: 9
# Random Number: 10
# Random Number: 10
# Random Number: 10
# Random Number: 7
# Random Number: 8
# Random Number: 9
# Random Number: 9
# Random Number: 7
# Random Number: 6
# Random Number: 7
# Random Number: 6
# Random Number: 6
# Random Number: 6
# Random Number: 10
# Random Number: 9
# Random Number: 9
# Random Number: 7
# Random Number: 8
# Random Number: 10
# Random Number: 9
# Random Number: 8
# Random Number: 7
# Random Number: 7
# Random Number: 7
# Random Number: 7
# Random Number: 8
# Random Number: 9
# Random Number: 6
# Random Number: 6
# Random Number: 10
# Random Number: 8
# Random Number: 10
# Random Number: 7
# Random Number: 9
# Random Number: 6
# Random Number: 6
# Random Number: 8
# Random Number: 7
# Random Number: 10
# ...

# %% [markdown]
# # 6. Functions
#
# Functions allow us to reuse code and make it more organized.

# %% [markdown]
# __`Step 8`__ Define and call functions with parameters and return values.

# %%
# Function with parameters and return value
def my_function(x):
    return x * 2

# Call the function
result = my_function(5)
print(result)  # Output: 15
# Out:
# 10

# %% [markdown]
# __`Step 8a`__ Define functions without parameters.

# %%
# Function without parameters
def no_param_function():
    print(my_list)
# Call the function
no_param_function()  # Output: [0, 1, 2, 4, 5, 5, 6]
# Out:
# [0, 1, 2, 4, 5, 5, 6]

# %% [markdown]
# __`Step 8b`__ Define functions with multiple parameters.

# %%
# Function with multiple parameters
def multi_param_function(x: int, y: int) -> int:
    return x + y

# Call with positional arguments

multi_param_function(5, 10)  # Output: 15

# Call with keyword arguments
multi_param_function(x=5, y=10)  # Output: 15
# Out:
# 15

# %% [markdown]
# __`Step 8c`__ Define functions that return multiple values.

# %%
# Function returning multiple values
my_tuple = (1, "hello", 3.14)
def return_multiple() -> tuple:
    return my_tuple[1], my_tuple[2]
# Call the function and unpack return values
values = return_multiple()
len(values)  # Output: <class 'tuple'>
# Out:
# 2

# %% [markdown]
# __`Step 8d`__ Define nested functions (functions inside functions).

# %%
# Function with nested function
def big_function(x):
    def nested_function_1(y):
        return y * 2
    
    def nested_function_2(z):
        return z + 5
    
    if x < 10:
        return nested_function_1(x)
    else:
        return nested_function_2(x)

print(big_function(5))  # Output: 10 (5 * 2)
print(big_function(15))  # Output: 20 (15 + 5)
# Create a function that doubles values
def double_value(x):
    return x * 2
# Out:
# 10
# 20

# %% [markdown]
# # 7. String Operations
#
# Strings are sequences of characters. Python provides many useful string methods.

# %% [markdown]
# __`Step 9`__ Perform common string operations.

# %%
string_1 = "Hello"
string_2 = "World"
# String creation and concatenation
concatenated_string = string_1 + " " + string_2  # Output: 'Hello World'
# String methods
## .lower(), .upper(), .replace()
lower_string = concatenated_string.lower()  # Output: 'hello world'
print(lower_string)  # Output: 'hello world'
upper_string = concatenated_string.upper()  # Output: 'HELLO WORLD'
print(upper_string)  # Output: 'HELLO WORLD'
# String formatting
age = 18
## f-strings, .format()
formatted_string_f = f"My age is {age}."  # Output: 'My age is 18.'
formatted_string_format = "My age is {} which doubled is {}.".format(age, age * 2)  # Output: 'My age is 18 which doubled is 36.'
print(formatted_string_f)  # Output: 'My age is 18.'
# Out:
# hello world
# HELLO WORLD
# My age is 18.

# %% [markdown]
# # 8. List Comprehensions
#
# List comprehensions provide a concise way to create lists.

# %% [markdown]
# __`Step 10`__ Use list comprehensions to create and filter lists.

# %%
# Create a list of squares
squares = [x**2 for x in range(10)]  # Output: [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# Filter list with condition
filtered_squares = [x for x in squares if x > 10]  # Output: [16, 25, 36, 49, 64, 81]

# Create list of dictionaries
[{"number": x, "square": x**2} for x in range(10)]  # Output: [{'number': 0, 'square': 0}, {'number': 1, 'square': 1}, ..., {'number': 9, 'square': 81}]
# Out:
# [{'number': 0, 'square': 0},
#  {'number': 1, 'square': 1},
#  {'number': 2, 'square': 4},
#  {'number': 3, 'square': 9},
#  {'number': 4, 'square': 16},
#  {'number': 5, 'square': 25},
#  {'number': 6, 'square': 36},
#  {'number': 7, 'square': 49},
#  {'number': 8, 'square': 64},
#  {'number': 9, 'square': 81}]

# %% [markdown]
# # 9. Working with Files
#
# File I/O operations are essential for data science work.

# %% [markdown]
# __`Step 11`__ Read and work with the Exercise1.xlsx file using pandas.

# %%
! ls data
# Out:
# Exercise1.xlsx

# %%
import pandas as pd

# Read the Excel file sheet_name='ClassifiedData', index_col='ID')
path = 'data/Exercise1.xlsx'

df = pd.read_excel(path, sheet_name='ClassifiedData', index_col='ID')
# Display the first few rows of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8000 entries, 1001 to 10999
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   BD1        8000 non-null   int64
#  1   BD2        8000 non-null   int64
#  2   BD3        8000 non-null   int64
#  3   BD4        8000 non-null   int64
#  4   BD5        8000 non-null   int64
#  5   BD6        8000 non-null   int64
#  6   BD7        8000 non-null   int64
#  7   BD8        8000 non-null   int64
#  8   BD9        8000 non-null   int64
#  9   DrugPlant  8000 non-null   int64
# dtypes: int64(10)
# memory usage: 687.5 KB

# %% [markdown]
# # 10. NumPy Basics
#
# NumPy provides efficient numerical operations on arrays.

# %% [markdown]
# __`Step 12`__ Use NumPy arrays for mathematical operations.

# %%
import numpy as np
my_list_2 = [2.5,3,4,5] 
# Create arrays
my_np_array_1 = np.array(my_list_2, dtype=int)  # This will create a NumPy array from the list of squares
my_np_array_2 = np.ones(4, dtype=int)  # Create an array of ones with length 5 
print(my_np_array_2)  # Output: [2 3 4 5]

print(my_np_array_1)  # Output: [2 3 4 5]
# Element-wise operations

print(my_np_array_2 + my_np_array_1)  # Output: [3 4 5 6 6]
print(my_np_array_2 * my_np_array_1)  # Output: [2 3 4 5 5]
print(my_np_array_2.dot(my_np_array_1))  # Output: [2 3 4 5 5]

# Statistical operations\
mean_value = my_np_array_1.mean()  # Output: 3.5
median_value = np.median(my_np_array_1)  # Output: 3.5
std_dev = my_np_array_1.std()  # Output: 1.118
print(f"Mean: {mean_value}, Median: {median_value}, Standard Deviation: {std_dev}")
# Out:
# [1 1 1 1]
# [2 3 4 5]
# [3 4 5 6]
# [2 3 4 5]
# 14
# Mean: 3.5, Median: 3.5, Standard Deviation: 1.118033988749895

# %% [markdown]
# # 11. Pandas DataFrame Operations
#
# Pandas DataFrames are the primary data structure for data science in Python.

# %% [markdown]
# __`Step 13`__ Perform common DataFrame operations.

# %%
# Load the data
type(df)  # Output: <class 'pandas.core.frame.DataFrame'>
# Select single column
# difference beween loc and iloc
df.loc[:, 'BD1']  # Output: Series with 'BD1' column
df.iloc[:, 0]  # Output: Series with the first column (BD1 in this DataFrame)
# Select multiple columns
df.loc[:, ['BD1', 'BD2', 'DrugPlant']]


# Filter rows
df[df['BD1'] > 100]  # Output: DataFrame with
# whn I want them equal to something the sign is == not >
df[df['BD1'] == 100]  # Output: DataFrame with rows where 'BD1' is equal to 100
# Out:
# Empty DataFrame
# Columns: [BD1, BD2, BD3, BD4, BD5, BD6, BD7, BD8, BD9, DrugPlant]
# Index: []

# %% [markdown]
# __`Step 14`__ Use groupby and aggregation functions.

# %%
# Group by and calculate mean

df.groupby('DrugPlant')['BD1'].mean()  # Output: Series with mean 'BD1' for each 'DrugPlant' category
# Count occurrences
df['DrugPlant'].value_counts()  # Output: Series with count of each unique value in 'DrugPlant' column

# Multiple aggregations
df.groupby('DrugPlant')['BD1'].agg(['mean', 'median', 'std'])  # Output: DataFrame with mean, median, and std of 'BD1' for each 'DrugPlant' category
# Out:
#                  mean  median         std
# DrugPlant
# 0          899.088838   894.0  201.922810
# 1          892.603352   889.0  206.128322

# %% [markdown]
# # 12. Exception Handling
#
# Exception handling allows us to gracefully handle errors.

# %% [markdown]
# __`Step 15`__ Use try/except blocks to handle errors.

# %%
# Example 1: Division by zero

try:
    result = 10 / 0

except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
    result = 10 / 1

#Example 2: Key error
data = {'name': 'John', 'age': 25}
try:
    print(data['email'])  # This key doesn't exist
except KeyError:
    print("Error: Key not found.")
    data['email'] = "Email not found"

# Example 3: General exception
values = [1, 2, 3]
try:
    print(values[10])  # Index out of range
except IndexError:
    print("Error: Index out of range.") 
    print(values[-1])
# Out:
# Error: Division by zero is not allowed.
# Error: Key not found.
# Error: Index out of range.
# 3

# %% [markdown]
# # Summary
#
# This notebook covered essential Python concepts for data science:
#
# ## Core Data Structures
# 1. **Data types**: int, float, str, bool, list, dict
# 2. **Lists**: Creating, accessing, modifying, and iterating
# 3. **Dictionaries**: Key-value storage, access, and manipulation
#
# ## Control Flow
# 4. **Conditionals**: if/elif/else statements for decision making
# 5. **Loops**: for loops, while loops, and enumerate()
#
# ## Functions (Comprehensive Coverage)
# 6. **Function Definition and Calling**: Parameters, return values, and default arguments
# 7. **Functions without parameters**: Simple functions with no inputs
# 8. **Functions with multiple parameters**: Positional and keyword arguments
# 9. **Variable length arguments**: *args for multiple positional arguments and **kwargs for keyword arguments
# 10. **Lambda functions**: Anonymous functions, map(), and filter() operations
# 11. **Multiple return values**: Tuple unpacking and returning multiple values
# 12. **Nested functions**: Closures and functions that return functions
#
# ## Data Manipulation
# 13. **String Operations**: Concatenation, methods, and formatting
# 14. **List Comprehensions**: Concise syntax for creating and filtering lists
# 15. **File I/O**: Reading data from Excel files using pandas
#
# ## Data Science Libraries
# 16. **NumPy**: Array creation, element-wise operations, and statistical functions
# 17. **Pandas**: DataFrames, column/row selection, filtering, and aggregation
#
# ## Error Handling
# 18. **Exception Handling**: try/except blocks, specific exceptions, and error messages
#
# These fundamentals are crucial for building robust data science pipelines and machine learning models!

# %%
import random
from matplotlib import pyplot as plt
# poisson distribution
chisquare = np.random.exponential(2, 100000)
plt.hist(chisquare, bins=30)
plt.show()

# %%
index_list_1 = np.random.randint(0, len(chisquare), 20000)
index_list_2 = np.random.randint(0, len(chisquare), 20000)  
index_list_3 = np.random.randint(0, len(chisquare), 20000)

chisquare_drawn_1 = chisquare[index_list_1]
chisquare_drawn_2 = chisquare[index_list_2]
chisquare_drawn_3 = chisquare[index_list_3]
print(chisquare_drawn_3)  # Output: Array of 2000 random values drawn from the 'chisquare' array
# Out:
# [1.72401752 2.05179028 0.31193197 ... 0.4913935  0.98217812 0.88372921]

# %%
np.random.shuffle(chisquare_drawn_3)  # Shuffle in place

# %%
# plot chisquare_drawn_1
plt.hist(chisquare_drawn_1, bins=30)
plt.title("Histogram of Chisquare Drawn 1")
plt.show()

plt.hist(chisquare_drawn_2, bins=30)
plt.title("Histogram of Chisquare Drawn 1")
plt.show()

# %%
np.random.shuffle(chisquare_drawn_2)  # Shuffle the first drawn array to create a new one

sum_of_drawn = (chisquare_drawn_2 + chisquare_drawn_1 + chisquare_drawn_3) / 10
len(sum_of_drawn)  # Output: 10
# Out:
# 20000

# %%
plt.hist(sum_of_drawn, bins=30)
plt.title("Histogram of Sum of Drawn")
plt.show()
