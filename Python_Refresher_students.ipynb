# %% [markdown]
# # Python Refresher for Data Science
#
# This notebook provides a practical refresher of Python fundamentals essential for data science, using real data from the Exercise1.xlsx file.

# %% [markdown]
# # 1. Data Types and Variables
#
# Python has several basic data types that are fundamental to working with data:
# - **int**: Integers (whole numbers)
# - **float**: Floating-point numbers (decimals)
# - **str**: Strings (text)
# - **bool**: Boolean (True/False)
# - **list**: Ordered collection of items
# - **dict**: Unordered collection of key-value pairs

# %% [markdown]
# __`Step 1`__ Create variables of different types and check their data type using the `type()` function.

# %%
# Integer

# Float

# String

# Boolean

# %% [markdown]
# # 2. Lists and Basic Operations
#
# Lists are ordered collections that can hold multiple items. They are mutable (can be changed) and are indexed starting from 0.

# %% [markdown]
# __`Step 2`__ Create a list and access elements using indexing.

# %%
# Create a list of features

# Access elements by index

# Get length of list

# %% [markdown]
# __`Step 3`__ Modify lists using append, insert, and remove operations.

# %%
# Start with a list

# Append (add to end)

# Insert at specific position

# Remove specific item

# %% [markdown]
# # 3. Dictionaries
#
# Dictionaries store data as key-value pairs. They are very useful for organizing related data.

# %% [markdown]
# __`Step 4`__ Create and manipulate dictionaries.

# %%
# Create a dictionary

# Access values using keys

# Add new key-value pair

# Get all keys and values

# %% [markdown]
# # 4. Control Flow: Conditionals (if/else)
#
# Conditionals allow us to execute different code based on conditions.

# %% [markdown]
# __`Step 5`__ Use if/else statements to make decisions.

# %% [markdown]
# # 5. Loops: for and while
#
# Loops allow us to repeat code multiple times.

# %% [markdown]
# __`Step 6`__ Use for loops to iterate over lists.

# %%
# For loop over a list

# For loop with index

# %% [markdown]
# __`Step 7`__ Use while loops for conditional repetition.

# %%
# While loop

# %% [markdown]
# # 6. Functions
#
# Functions allow us to reuse code and make it more organized.

# %% [markdown]
# __`Step 8`__ Define and call functions with parameters and return values.

# %%
# Function with parameters and return value


# Call the function

# %% [markdown]
# __`Step 8a`__ Define functions without parameters.

# %%
# Function without parameters

# Call the function

# %% [markdown]
# __`Step 8b`__ Define functions with multiple parameters.

# %%
# Function with multiple parameters


# Call with positional arguments


# Call with keyword arguments

# %% [markdown]
# __`Step 8c`__ Define functions that return multiple values.

# %%
# Function returning multiple values

# Call the function and unpack return values

# %% [markdown]
# __`Step 8d`__ Define nested functions (functions inside functions).

# %%
# Function with nested function

# Create a function that doubles values

# Create a function that triples values

# %% [markdown]
# # 7. String Operations
#
# Strings are sequences of characters. Python provides many useful string methods.

# %% [markdown]
# __`Step 9`__ Perform common string operations.

# %%
# String creation and concatenation

# String methods
## .lower(), .upper(), .replace()

# String formatting
## f-strings, .format(), % formatting

# %% [markdown]
# # 8. List Comprehensions
#
# List comprehensions provide a concise way to create lists.

# %% [markdown]
# __`Step 10`__ Use list comprehensions to create and filter lists.

# %%
# Create a list of squares

# Filter list with condition

# Create list of dictionaries

# %% [markdown]
# # 9. Working with Files
#
# File I/O operations are essential for data science work.

# %% [markdown]
# __`Step 11`__ Read and work with the Exercise1.xlsx file using pandas.

# %%
import pandas as pd

# Read the Excel file sheet_name='ClassifiedData', index_col='ID')

# Display the first few rows of the DataFrame

# %% [markdown]
# # 10. NumPy Basics
#
# NumPy provides efficient numerical operations on arrays.

# %% [markdown]
# __`Step 12`__ Use NumPy arrays for mathematical operations.

# %%
import numpy as np

# Create arrays


# Element-wise operations


# Statistical operations

# %% [markdown]
# # 11. Pandas DataFrame Operations
#
# Pandas DataFrames are the primary data structure for data science in Python.

# %% [markdown]
# __`Step 13`__ Perform common DataFrame operations.

# %%
# Load the data

# Select single column


# Select multiple columns

# Filter rows

# %% [markdown]
# __`Step 14`__ Use groupby and aggregation functions.

# %%
# Group by and calculate mean


# Count occurrences


# Multiple aggregations

# %% [markdown]
# # 12. Exception Handling
#
# Exception handling allows us to gracefully handle errors.

# %% [markdown]
# __`Step 15`__ Use try/except blocks to handle errors.

# %%
# Example 1: Division by zero
result = 10 / 0

# Example 2: Key error
data = {'name': 'John', 'age': 25}
print(data['email'])  # This key doesn't exist

# Example 3: General exception
values = [1, 2, 3]
print(values[10])  # Index out of range

# %% [markdown]
# # Summary
#
# This notebook covered essential Python concepts for data science:
#
# ## Core Data Structures
# 1. **Data types**: int, float, str, bool, list, dict
# 2. **Lists**: Creating, accessing, modifying, and iterating
# 3. **Dictionaries**: Key-value storage, access, and manipulation
#
# ## Control Flow
# 4. **Conditionals**: if/elif/else statements for decision making
# 5. **Loops**: for loops, while loops, and enumerate()
#
# ## Functions (Comprehensive Coverage)
# 6. **Function Definition and Calling**: Parameters, return values, and default arguments
# 7. **Functions without parameters**: Simple functions with no inputs
# 8. **Functions with multiple parameters**: Positional and keyword arguments
# 9. **Variable length arguments**: *args for multiple positional arguments and **kwargs for keyword arguments
# 10. **Lambda functions**: Anonymous functions, map(), and filter() operations
# 11. **Multiple return values**: Tuple unpacking and returning multiple values
# 12. **Nested functions**: Closures and functions that return functions
#
# ## Data Manipulation
# 13. **String Operations**: Concatenation, methods, and formatting
# 14. **List Comprehensions**: Concise syntax for creating and filtering lists
# 15. **File I/O**: Reading data from Excel files using pandas
#
# ## Data Science Libraries
# 16. **NumPy**: Array creation, element-wise operations, and statistical functions
# 17. **Pandas**: DataFrames, column/row selection, filtering, and aggregation
#
# ## Error Handling
# 18. **Exception Handling**: try/except blocks, specific exceptions, and error messages
#
# These fundamentals are crucial for building robust data science pipelines and machine learning models!
